# %% [markdown]
# # Приклад 01: Швидкий чат через OpenAI SDK
#
# Цей ноутбук демонструє, як використовувати OpenAI SDK разом із Microsoft Foundry Local для швидких чат-взаємодій.
#
# ## Огляд
#
# Цей приклад показує:
# - Використання OpenAI Python SDK із Foundry Local
# - Роботу як з Azure OpenAI, так і з локальними конфігураціями Foundry
# - Реалізацію належної обробки помилок і стратегій резервування
# - Використання FoundryLocalManager для управління сервісами

# %% [markdown]
# ## Передумови
#
# Переконайтеся, що у вас:
# 1. Встановлено та запущено Foundry Local
# 2. Завантажено модель (наприклад, `foundry model run phi-4-mini`)
# 3. Встановлено необхідні пакети Python
#
# ### Встановлення залежностей

# %%
# Install required packages if not already installed
# !pip install openai foundry-local-sdk

# %% [markdown]
# ## Імпорт необхідних бібліотек

# %%
import os
import sys
from openai import OpenAI

try:
    from foundry_local import FoundryLocalManager
    FOUNDRY_SDK_AVAILABLE = True
    print("✅ Foundry Local SDK is available")
except ImportError:
    FOUNDRY_SDK_AVAILABLE = False
    print("⚠️ Foundry Local SDK not available, will use manual configuration")

# %% [markdown]
# ## Конфігурація
#
# Налаштуйте свою конфігурацію. Ви можете використовувати один із варіантів:
# 1. **Azure OpenAI** (хмарний сервіс)
# 2. **Foundry Local** (локальне прогнозування)
#
# ### Варіант 1: Конфігурація Azure OpenAI

# %%
# Azure OpenAI Configuration (uncomment and set your values)
# os.environ["AZURE_OPENAI_ENDPOINT"] = "https://your-resource.openai.azure.com"
# os.environ["AZURE_OPENAI_API_KEY"] = "your-api-key"
# os.environ["AZURE_OPENAI_API_VERSION"] = "2024-08-01-preview"
# os.environ["MODEL"] = "your-deployment-name"

# %% [markdown]
# ### Варіант 2: Локальна конфігурація Foundry

# %%
# Foundry Local Configuration
MODEL_ALIAS = "phi-4-mini"  # Change this to your preferred model
BASE_URL = "http://localhost:8000"  # Default Foundry Local URL
API_KEY = ""  # Usually not needed for local

# %% [markdown]
# ## Ініціалізація клієнта
#
# Створіть клієнт OpenAI на основі вашої конфігурації:

# %%
def create_client():
    """Create and configure OpenAI client."""
    
    # Check for Azure OpenAI configuration
    azure_endpoint = os.environ.get("AZURE_OPENAI_ENDPOINT")
    azure_api_key = os.environ.get("AZURE_OPENAI_API_KEY")
    azure_api_version = os.environ.get("AZURE_OPENAI_API_VERSION", "2024-08-01-preview")
    
    if azure_endpoint and azure_api_key:
        # Azure OpenAI path
        model = os.environ.get("MODEL", "your-deployment-name")
        client = OpenAI(
            base_url=f"{azure_endpoint}/openai",
            api_key=azure_api_key,
            default_query={"api-version": azure_api_version},
        )
        print(f"🌐 Using Azure OpenAI with model: {model}")
        return client, model
    
    # Foundry Local path
    if FOUNDRY_SDK_AVAILABLE:
        try:
            # Use FoundryLocalManager for proper service management
            manager = FoundryLocalManager(MODEL_ALIAS)
            model_info = manager.get_model_info(MODEL_ALIAS)
            
            # Configure OpenAI client to use local Foundry service
            client = OpenAI(
                base_url=manager.endpoint,
                api_key=manager.api_key  # API key is not required for local usage
            )
            model = model_info.id
            print(f"🏠 Using Foundry Local SDK with model: {model}")
            return client, model
        except Exception as e:
            print(f"⚠️ Could not use Foundry SDK ({e}), falling back to manual configuration")
    
    # Fallback to manual configuration
    client = OpenAI(
        base_url=f"{BASE_URL}/v1",
        api_key=API_KEY
    )
    model = MODEL_ALIAS
    print(f"🔧 Using manual configuration with model: {model}")
    return client, model

# Initialize the client
client, model = create_client()

# %% [markdown]
# ## Простий приклад чату
#
# Давайте протестуємо просту взаємодію в чаті:

# %%
def chat_with_model(prompt, max_tokens=128):
    """Send a chat message to the model and get a response."""
    try:
        response = client.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": prompt}],
            max_tokens=max_tokens
        )
        
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {e}"

# Test with a simple prompt
prompt = "Say hello from Foundry Local and explain what you are in one sentence."
print(f"👤 User: {prompt}")
print("\n🤖 Assistant:")
response = chat_with_model(prompt)
print(response)

# %% [markdown]
# ## Інтерактивна сесія чату
#
# Спробуйте різні типи запитів, щоб побачити, як модель реагує:

# %%
# Example prompts to try
example_prompts = [
    "What are the benefits of edge AI?",
    "Explain the difference between local and cloud AI inference.",
    "Write a short Python function to calculate the factorial of a number.",
    "What is Microsoft Foundry Local?"
]

for i, prompt in enumerate(example_prompts, 1):
    print(f"\n{'='*50}")
    print(f"Example {i}: {prompt}")
    print(f"{'='*50}")
    
    response = chat_with_model(prompt, max_tokens=200)
    print(response)

# %% [markdown]
# ## Розширене використання: Стримінг відповідей
#
# Для довших відповідей стримінг може забезпечити кращий досвід користувача:

# %%
def chat_with_streaming(prompt, max_tokens=300):
    """Send a chat message with streaming response."""
    try:
        stream = client.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": prompt}],
            max_tokens=max_tokens,
            stream=True
        )
        
        print("🤖 Assistant (streaming):")
        full_response = ""
        for chunk in stream:
            if chunk.choices[0].delta.content is not None:
                content = chunk.choices[0].delta.content
                print(content, end="", flush=True)
                full_response += content
        print("\n")  # New line after streaming
        return full_response
    except Exception as e:
        return f"Error: {e}"

# Test streaming with a longer prompt
streaming_prompt = "Explain the advantages of running AI models locally on device versus in the cloud. Include privacy, latency, and cost considerations."
print(f"👤 User: {streaming_prompt}\n")
streaming_response = chat_with_streaming(streaming_prompt)

# %% [markdown]
# ## Обробка помилок і діагностика
#
# Давайте перевіримо статус сервісу та доступні моделі:

# %%
def check_service_health():
    """Check Foundry Local service health."""
    try:
        # Try to list available models
        models_response = client.models.list()
        models = [model.id for model in models_response.data]
        
        print("✅ Service is healthy")
        print(f"📋 Available models: {models}")
        print(f"🎯 Current model: {model}")
        
        if model in models:
            print("✅ Current model is available")
        else:
            print("⚠️ Current model may not be loaded")
            
    except Exception as e:
        print(f"❌ Service check failed: {e}")
        print("\n🔧 Troubleshooting tips:")
        print("1. Make sure Foundry Local is running")
        print("2. Check if a model is loaded: foundry service ps")
        print("3. Verify the endpoint URL is correct")

check_service_health()

# %% [markdown]
# ## Тестування власних запитів
#
# Використовуйте наступну комірку для перевірки ваших власних запитів:

# %%
# Enter your custom prompt here
custom_prompt = "Write a haiku about artificial intelligence running on edge devices."

print(f"👤 User: {custom_prompt}\n")
custom_response = chat_with_model(custom_prompt, max_tokens=100)
print(f"🤖 Assistant: {custom_response}")

# %% [markdown]
# ## Резюме
#
# Цей блокнот продемонстрував:
#
# 1. **✅ Налаштування клієнта**: Як налаштувати OpenAI SDK з Foundry Local
# 2. **✅ Базовий чат**: Прості взаємодії запит-відповідь
# 3. **✅ Стрімінг**: Генерація відповідей у реальному часі
# 4. **✅ Обробка помилок**: Надійна обробка помилок і діагностика
# 5. **✅ Стан сервісу**: Перевірка доступності моделі та статусу сервісу
#
# ### Наступні кроки
#
# - **Sample 02**: Розширена інтеграція SDK із підтримкою Azure OpenAI
# - **Sample 04**: Створення чат-додатку Chainlit
# - **Sample 05**: Системи оркестрації з багатьма агентами
# - **Sample 06**: Інтелектуальне маршрутизація моделей
#
# ### Основні переваги Foundry Local
#
# - 🔒 **Конфіденційність**: Дані ніколи не залишають ваш пристрій
# - ⚡ **Швидкість**: Локальне прогнозування з низькою затримкою
# - 💰 **Вартість**: Відсутність витрат на використання API
# - 🔌 **Офлайн**: Працює без підключення до інтернету
# - 🛠️ **Сумісність**: API, сумісний з OpenAI
